# %%
import pandas as pd

customers = pd.read_csv('../../datafile/kaggle/Target_ecommerce/customers.csv')
geolocation = pd.read_csv('../../datafile/kaggle/Target_ecommerce/geolocation.csv')
items = pd.read_csv('../../datafile/kaggle/Target_ecommerce/order_items.csv')
orders = pd.read_csv('../../datafile/kaggle/Target_ecommerce/orders.csv')
payments = pd.read_csv('../../datafile/kaggle/Target_ecommerce/payments.csv')
products = pd.read_csv('../../datafile/kaggle/Target_ecommerce/products.csv')
sellers = pd.read_csv('../../datafile/kaggle/Target_ecommerce/sellers.csv')
