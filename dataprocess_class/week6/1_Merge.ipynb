# %% [markdown]
# pandas provides a single function, merge(), as the entry point for all standard database join operations between DataFrame or named Series objects:

# %% [markdown]
# ```python
# pd.merge(
#     left,
#     right,
#     how="inner",
#     on=None,
#     left_on=None,
#     right_on=None,
#     left_index=False,
#     right_index=False,
#     sort=True,
#     suffixes=("_x", "_y"),
#     copy=True,
#     indicator=False,
#     validate=None,
# )
# ```

# %% [markdown]
# - left: A DataFrame or named Series object.
#
# - right: Another DataFrame or named Series object.
#
# - on: Column or index level names to join on. Must be found in both the left and right DataFrame and/or Series objects. If not passed and left_index and right_index are False, the intersection of the columns in the DataFrames and/or Series will be inferred to be the join keys.
#
# - left_on: Columns or index levels from the left DataFrame or Series to use as keys. Can either be column names, index level names, or arrays with length equal to the length of the DataFrame or Series.
#
# - right_on: Columns or index levels from the right DataFrame or Series to use as keys. Can either be column names, index level names, or arrays with length equal to the length of the DataFrame or Series.
#
# - left_index: If True, use the index (row labels) from the left DataFrame or Series as its join key(s). In the case of a DataFrame or Series with a MultiIndex (hierarchical), the number of levels must match the number of join keys from the right DataFrame or Series.
#
# - right_index: Same usage as left_index for the right DataFrame or Series
#
# - how: One of 'left', 'right', 'outer', 'inner', 'cross'. Defaults to inner. See below for more detailed description of each method.
#
# - sort: Sort the result DataFrame by the join keys in _lexicographical_**(Alphabetic)** order. Defaults to True, setting to False will improve performance substantially in many cases.
#
# - suffixes (접미사): **A tuple of string suffixes to apply to overlapping columns. Defaults to ('_x', '_y').**
#
# \\
#
# - copy: Always copy data (default True) from the passed DataFrame or named Series objects, even when reindexing is not necessary. Cannot be avoided in many cases but may improve performance / memory usage. The cases where copying can be avoided are somewhat pathological but this option is provided nonetheless.
#
# - indicator: Add a column to the output DataFrame called _merge with information on the source of each row. _merge is Categorical-type and takes on a value of left_only for observations whose merge key only appears in 'left' DataFrame or Series, right_only for observations whose merge key only appears in 'right' DataFrame or Series, and both if the observation’s merge key is found in both.
#
# - validate : string, default None. If specified, checks if merge is of specified type.

# %%
import pandas as pd

# %%
left = pd.DataFrame(
    {
        "key": ["K0", "K1", "K2", "K4"],
        "midterm": ["A0", "A1", "A2", "A3"],
        "final": ["B0", "B1", "B2", "B3"],
    }
)
left
# Out:
#   key midterm final
# 0  K0      A0    B0
# 1  K1      A1    B1
# 2  K2      A2    B2
# 3  K4      A3    B3

# %%
right = pd.DataFrame(
    {
        "key": ["K0", "K-1", "K2", "K3"],
        "midterm": ["C0", "C1", "C2", "C3"],
        "final": ["D0", "D1", "D2", "D3"],
    }
)
right
# Out:
#    key midterm final
# 0   K0      C0    D0
# 1  K-1      C1    D1
# 2   K2      C2    D2
# 3   K3      C3    D3

# %%
result = pd.merge(left, right, on="key",suffixes=('_data','_algorithm'))
result
# Out:
#   key midterm_data final_data midterm_algorithm final_algorithm
# 0  K0           A0         B0                C0              D0
# 1  K2           A2         B2                C2              D2

# %%
result = pd.merge(left, right, how='outer', on="key")
result
# Out:
#    key midterm_x final_x midterm_y final_y
# 0  K-1       NaN     NaN        C1      D1
# 1   K0        A0      B0        C0      D0
# 2   K1        A1      B1       NaN     NaN
# 3   K2        A2      B2        C2      D2
# 4   K3       NaN     NaN        C3      D3
# 5   K4        A3      B3       NaN     NaN

# %% [markdown]
# ## multiple keys

# %% [markdown]
# Only the keys appearing in left and right are present (the intersection), since how='inner' by default.

# %%
left = pd.DataFrame(
    {
        "key1": ["K0", "K0", "K1", "K2"],
        "key2": ["K0", "K1", "K0", "K1"],
        "A": ["A0", "A1", "A2", "A3"],
        "B": ["B0", "B1", "B2", "B3"],
    }
)
left
# Out:
#   key1 key2   A   B
# 0   K0   K0  A0  B0
# 1   K0   K1  A1  B1
# 2   K1   K0  A2  B2
# 3   K2   K1  A3  B3

# %%
right = pd.DataFrame(
    {
        "key1": ["K0", "K1", "K1", "K2"],
        "key2": ["K0", "K0", "K0", "K0"],
        "C": ["C0", "C1", "C2", "C3"],
        "D": ["D0", "D1", "D2", "D3"],
    }
)
right
# Out:
#   key1 key2   C   D
# 0   K0   K0  C0  D0
# 1   K1   K0  C1  D1
# 2   K1   K0  C2  D2
# 3   K2   K0  C3  D3

# %%
result = pd.merge(left, right, on=["key1", "key2"], how='inner')
result
# Out:
#   key1 key2   A   B   C   D
# 0   K0   K0  A0  B0  C0  D0
# 1   K1   K0  A2  B2  C1  D1
# 2   K1   K0  A2  B2  C2  D2

# %%
result = pd.merge(left, right, on=["key1"], how='inner')
result
# Out:
#   key1 key2_x   A   B key2_y   C   D
# 0   K0     K0  A0  B0     K0  C0  D0
# 1   K0     K1  A1  B1     K0  C0  D0
# 2   K1     K0  A2  B2     K0  C1  D1
# 3   K1     K0  A2  B2     K0  C2  D2
# 4   K2     K1  A3  B3     K0  C3  D3

# %%
result = pd.merge(left, right, on=["key1", "key2"], how='outer')
result
# Out:
#   key1 key2    A    B    C    D
# 0   K0   K0   A0   B0   C0   D0
# 1   K0   K1   A1   B1  NaN  NaN
# 2   K1   K0   A2   B2   C1   D1
# 3   K1   K0   A2   B2   C2   D2
# 4   K2   K0  NaN  NaN   C3   D3
# 5   K2   K1   A3   B3  NaN  NaN

# %% [markdown]
# ## left joing :

# %% [markdown]
# use keys from left frame only = containing all key values from left df

# %%
display(left)
right
# Out:
#   key1 key2   A   B
# 0   K0   K0  A0  B0
# 1   K0   K1  A1  B1
# 2   K1   K0  A2  B2
# 3   K2   K1  A3  B3
#   key1 key2   C   D
# 0   K0   K0  C0  D0
# 1   K1   K0  C1  D1
# 2   K1   K0  C2  D2
# 3   K2   K0  C3  D3

# %%
result1 = pd.merge(left,right,left_on=['key2'],right_on=['key1'],sort=True)
result1
# Out:
#   key1_x key2_x   A   B key1_y key2_y   C   D
# 0     K0     K0  A0  B0     K0     K0  C0  D0
# 1     K1     K0  A2  B2     K0     K0  C0  D0
# 2     K0     K1  A1  B1     K1     K0  C1  D1
# 3     K0     K1  A1  B1     K1     K0  C2  D2
# 4     K2     K1  A3  B3     K1     K0  C1  D1
# 5     K2     K1  A3  B3     K1     K0  C2  D2

# %%
result = pd.merge(left, right, how="left", on=["key1", "key2"])
result
# Out:
#   key1 key2   A   B    C    D
# 0   K0   K0  A0  B0   C0   D0
# 1   K0   K1  A1  B1  NaN  NaN
# 2   K1   K0  A2  B2   C1   D1
# 3   K1   K0  A2  B2   C2   D2
# 4   K2   K1  A3  B3  NaN  NaN

# %%
result = pd.merge(right,left,how="right", on=["key1", "key2"])
result # changes col order, but identical with left join process
# Out:
#   key1 key2    C    D   A   B
# 0   K0   K0   C0   D0  A0  B0
# 1   K0   K1  NaN  NaN  A1  B1
# 2   K1   K0   C1   D1  A2  B2
# 3   K1   K0   C2   D2  A2  B2
# 4   K2   K1  NaN  NaN  A3  B3

# %% [markdown]
# ## right join

# %%
result = pd.merge(left, right, how="right", on=["key1", "key2"])
result
# Out:
#   key1 key2    A    B   C   D
# 0   K0   K0   A0   B0  C0  D0
# 1   K1   K0   A2   B2  C1  D1
# 2   K1   K0   A2   B2  C2  D2
# 3   K2   K0  NaN  NaN  C3  D3

# %% [markdown]
# ### outer join

# %%
result = pd.merge(left, right, how="outer", on=["key1", "key2"])
result
# Out:
#   key1 key2    A    B    C    D
# 0   K0   K0   A0   B0   C0   D0
# 1   K0   K1   A1   B1  NaN  NaN
# 2   K1   K0   A2   B2   C1   D1
# 3   K1   K0   A2   B2   C2   D2
# 4   K2   K0  NaN  NaN   C3   D3
# 5   K2   K1   A3   B3  NaN  NaN

# %% [markdown]
# ## cross
#
# - generating all product values

# %%
result = pd.merge(left, right, how="cross")
result
# Out:
#    key1_x key2_x   A   B key1_y key2_y   C   D
# 0      K0     K0  A0  B0     K0     K0  C0  D0
# 1      K0     K0  A0  B0     K1     K0  C1  D1
# 2      K0     K0  A0  B0     K1     K0  C2  D2
# 3      K0     K0  A0  B0     K2     K0  C3  D3
# 4      K0     K1  A1  B1     K0     K0  C0  D0
# 5      K0     K1  A1  B1     K1     K0  C1  D1
# 6      K0     K1  A1  B1     K1     K0  C2  D2
# 7      K0     K1  A1  B1     K2     K0  C3  D3
# 8      K1     K0  A2  B2     K0     K0  C0  D0
# 9      K1     K0  A2  B2     K1     K0  C1  D1
# 10     K1     K0  A2  B2     K1     K0  C2  D2
# 11     K1     K0  A2  B2     K2     K0  C3  D3
# 12     K2     K1  A3  B3     K0     K0  C0  D0
# 13     K2     K1  A3  B3     K1     K0  C1  D1
# 14     K2     K1  A3  B3     K1     K0  C2  D2
# 15     K2     K1  A3  B3     K2     K0  C3  D3

# %% [markdown]
# ### joining on index `join`

# %% [markdown]
# DataFrame.join() is a convenient method for combining the columns of two potentially differently-indexed DataFrames into a single result DataFrame. Here is a very basic example:

# %%
left = pd.DataFrame(
    {"A": ["A0", "A1", "A2"], "B": ["B0", "B1", "B2"]}, index=["K0", "K1", "K2"]
)
left
# Out:
#      A   B
# K0  A0  B0
# K1  A1  B1
# K2  A2  B2

# %%
right = pd.DataFrame(
    {"C": ["C0", "C2", "C3"], "D": ["D0", "D2", "D3"]}, index=["K0", "K2", "K3"]
)
right
# Out:
#      C   D
# K0  C0  D0
# K2  C2  D2
# K3  C3  D3

# %%
# Join by the left keys
result = left.join(right)
result
# Out:
#      A   B    C    D
# K0  A0  B0   C0   D0
# K1  A1  B1  NaN  NaN
# K2  A2  B2   C2   D2

# %%
result = left.join(right, how="outer")
result
# Out:
#       A    B    C    D
# K0   A0   B0   C0   D0
# K1   A1   B1  NaN  NaN
# K2   A2   B2   C2   D2
# K3  NaN  NaN   C3   D3

# %%
result = left.join(right, how="inner")
result
# Out:
#      A   B   C   D
# K0  A0  B0  C0  D0
# K2  A2  B2  C2  D2

# %%
display(left)
right
# Out:
#      A   B
# K0  A0  B0
# K1  A1  B1
# K2  A2  B2
#      C   D
# K0  C0  D0
# K2  C2  D2
# K3  C3  D3

# %%
result = pd.merge(left, right, left_index=True,right_index=True, how="left")
result # index를 기준으로 합쳐진다.
# Out:
#      A   B    C    D
# K0  A0  B0   C0   D0
# K1  A1  B1  NaN  NaN
# K2  A2  B2   C2   D2

# %%
result = pd.merge(left, right, left_index=True, right_index=True, how="inner")
result
# Out:
#      A   B   C   D
# K0  A0  B0  C0  D0
# K2  A2  B2  C2  D2

# %%
result = pd.merge(left,right,left_index=True,right_index=True,how='right')
result
# Out:
#       A    B   C   D
# K0   A0   B0  C0  D0
# K2   A2   B2  C2  D2
# K3  NaN  NaN  C3  D3

# %% [markdown]
# ### Joining key columns on an index

# %%
left = pd.DataFrame(
    {
        "A": ["A0", "A1", "A2", "A3"],
        "B": ["B0", "B1", "B2", "B3"],
        "key": ["K0", "K1", "K0", "K1"],
    }
)
left
# Out:
#     A   B key
# 0  A0  B0  K0
# 1  A1  B1  K1
# 2  A2  B2  K0
# 3  A3  B3  K1

# %%
right = pd.DataFrame({"C": ["C0", "C1"], "D": ["D0", "D1"]}, index=["K0", "K1"])
right
# Out:
#      C   D
# K0  C0  D0
# K1  C1  D1

# %%
result = left.join(right, on="key")
result
# Out:
#     A   B key   C   D
# 0  A0  B0  K0  C0  D0
# 1  A1  B1  K1  C1  D1
# 2  A2  B2  K0  C0  D0
# 3  A3  B3  K1  C1  D1

# %%
#
result = pd.merge(
    left, right,left_on="key", right_index=True,sort=False
)
result
# Out:
#     A   B key   C   D
# 0  A0  B0  K0  C0  D0
# 1  A1  B1  K1  C1  D1
# 2  A2  B2  K0  C0  D0
# 3  A3  B3  K1  C1  D1

# %%
result = pd.merge(
    left, right,left_on="key", right_index=True, how="left", sort=False
)
result
# Out:
#     A   B key   C   D
# 0  A0  B0  K0  C0  D0
# 1  A1  B1  K1  C1  D1
# 2  A2  B2  K0  C0  D0
# 3  A3  B3  K1  C1  D1
